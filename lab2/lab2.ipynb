# %%
from google.colab import files
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


#PART 1
files.upload()

data = pd.read_csv('wine.data')
data.columns = ['class', 'Alcohol', 'Malicacid', 'Ash',
                'Alcalinity_of_ash', 'Magnesium', 'Total_phenols', 'Flavanoids',
                'Nonflavanoid_phenols', 'Proanthocyanins', 'Color_intensity', 'Hue',
                'diluted_wines', 'Proline']
# Out:
#      <input type="file" id="files-9e85d447-b2e3-4696-a30e-e650307cc9e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e85d447-b2e3-4696-a30e-e650307cc9e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# sample_data  wine.data

# %%
data.head()
# Out:
#    class  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    13.20       1.78  2.14               11.2        100
# 1      1    13.16       2.36  2.67               18.6        101
# 2      1    14.37       1.95  2.50               16.8        113
# 3      1    13.24       2.59  2.87               21.0        118
# 4      1    14.20       1.76  2.45               15.2        112
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color_intensity   Hue  diluted_wines  Proline
# 0             4.38  1.05           3.40     1050
# 1             5.68  1.03           3.17     1185
# ...

# %%
data.tail()
# Out:
#      class  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 172      3    13.71       5.65  2.45               20.5         95
# 173      3    13.40       3.91  2.48               23.0        102
# 174      3    13.27       4.28  2.26               20.0        120
# 175      3    13.17       2.59  2.37               20.0        120
# 176      3    14.13       4.10  2.74               24.5         96
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 172           1.68        0.61                  0.52             1.06
# 173           1.80        0.75                  0.43             1.41
# 174           1.59        0.69                  0.43             1.35
# 175           1.65        0.68                  0.53             1.46
# 176           2.05        0.76                  0.56             1.35
#
#      Color_intensity   Hue  diluted_wines  Proline
# 172              7.7  0.64           1.74      740
# ...

# %%
#PART2
data.dtypes #cell types
# Out:
# class                     int64
# Alcohol                 float64
# Malicacid               float64
# Ash                     float64
# Alcalinity_of_ash       float64
# Magnesium                 int64
# Total_phenols           float64
# Flavanoids              float64
# Nonflavanoid_phenols    float64
# Proanthocyanins         float64
# Color_intensity         float64
# Hue                     float64
# diluted_wines           float64
# Proline                   int64
# dtype: object

# %%
data.info() #sample quantity
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 177 non-null    int64
#  1   Alcohol               177 non-null    float64
#  2   Malicacid             177 non-null    float64
#  3   Ash                   177 non-null    float64
#  4   Alcalinity_of_ash     177 non-null    float64
#  5   Magnesium             177 non-null    int64
#  6   Total_phenols         177 non-null    float64
#  7   Flavanoids            177 non-null    float64
#  8   Nonflavanoid_phenols  177 non-null    float64
#  9   Proanthocyanins       177 non-null    float64
#  10  Color_intensity       177 non-null    float64
#  11  Hue                   177 non-null    float64
#  12  diluted_wines         177 non-null    float64
#  13  Proline               177 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
data.isnull().sum()
# Out:
# class                   0
# Alcohol                 0
# Malicacid               0
# Ash                     0
# Alcalinity_of_ash       0
# Magnesium               0
# Total_phenols           0
# Flavanoids              0
# Nonflavanoid_phenols    0
# Proanthocyanins         0
# Color_intensity         0
# Hue                     0
# diluted_wines           0
# Proline                 0
# dtype: int64

# %%
data.describe()
# Out:
#             class     Alcohol   Malicacid         Ash  Alcalinity_of_ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
print(data)
# Out:
#      class  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0        1    13.20       1.78  2.14               11.2        100
# 1        1    13.16       2.36  2.67               18.6        101
# 2        1    14.37       1.95  2.50               16.8        113
# 3        1    13.24       2.59  2.87               21.0        118
# 4        1    14.20       1.76  2.45               15.2        112
# ..     ...      ...        ...   ...                ...        ...
# 172      3    13.71       5.65  2.45               20.5         95
# 173      3    13.40       3.91  2.48               23.0        102
# 174      3    13.27       4.28  2.26               20.0        120
# 175      3    13.17       2.59  2.37               20.0        120
# 176      3    14.13       4.10  2.74               24.5         96
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0             2.65        2.76                  0.26             1.28
# ...

# %%
data.corr() #correlations
# Out:
#                          class   Alcohol  Malicacid       Ash  \
# class                 1.000000 -0.321238   0.436127 -0.048260
# Alcohol              -0.321238  1.000000   0.099963  0.210964
# Malicacid             0.436127  0.099963   1.000000  0.164955
# Ash                  -0.048260  0.210964   0.164955  1.000000
# Alcalinity_of_ash     0.513963 -0.303350   0.286148  0.446698
# Magnesium            -0.198944  0.258742  -0.049049  0.287107
# Total_phenols        -0.717933  0.284543  -0.333512  0.128176
# Flavanoids           -0.846485  0.230133  -0.409324  0.114084
# Nonflavanoid_phenols  0.487215 -0.151445   0.291501  0.187354
# Proanthocyanins      -0.494887  0.127561  -0.217975  0.008082
# Color_intensity       0.268562  0.547883   0.250053  0.258643
# Hue                  -0.617690 -0.075375  -0.560854 -0.075181
# diluted_wines        -0.786428  0.057417  -0.366720  0.001503
# Proline              -0.631227  0.641068  -0.189512  0.222979
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# The dataset consists of 177 samples. There are 13 features in total. There are no null lines.

# %%
#PART3
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# Generate some data for this
# demonstration.
data = np.random.normal(170, 10, 250)

# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

plt.plot(x, p, 'k', linewidth=2)
title = "Fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)

plt.show()

# %%
data.hist(figsize = (15,15))
# Out:
# array([[<Axes: title={'center': 'class'}>,
#         <Axes: title={'center': 'Alcohol'}>,
#         <Axes: title={'center': 'Malicacid'}>,
#         <Axes: title={'center': 'Ash'}>],
#        [<Axes: title={'center': 'Alcalinity_of_ash'}>,
#         <Axes: title={'center': 'Magnesium'}>,
#         <Axes: title={'center': 'Total_phenols'}>,
#         <Axes: title={'center': 'Flavanoids'}>],
#        [<Axes: title={'center': 'Nonflavanoid_phenols'}>,
#         <Axes: title={'center': 'Proanthocyanins'}>,
#         <Axes: title={'center': 'Color_intensity'}>,
#         <Axes: title={'center': 'Hue'}>],
#        [<Axes: title={'center': 'diluted_wines'}>,
#         <Axes: title={'center': 'Proline'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
#PART4
from sklearn.model_selection import train_test_split

X = data.drop(['class'], axis=1)
y = data['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
plt.figure(figsize = (15, 8))
sns.scatterplot(x="Color_intensity", y="Hue", data = data, hue="Malicacid", palette="coolwarm")
# Out:
# <Axes: xlabel='Color_intensity', ylabel='Hue'>

# %%
from IPython.display import Image
Image('metrics.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
from sklearn.svm import SVC
model_SVC = SVC(kernel ='rbf', random_state = 4)
model_SVC.fit(X_train, y_train)

y_pred_svm = model_SVC.decision_function(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model_logistic = LogisticRegression()
model_logistic.fit(X_train, y_train)

y_pred_logistic = model_logistic.decision_function(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import roc_curve, auc

logistic_fpr, logistic_tpr, threshhold = roc_curve(y_test, y_pred_logistic)
auc_logistic = auc(logistic_fpr, logistic_tpr)

svm_fpr, svm_tpr, threshold = roc_curve(y_test, y_pred_svm)
auc_svm = auc(svm_fpr, svm_fpr)

plt.figure(figsize(5,5), dpi=100)
plt.plot(svm_fpr, svm_tpr, linestyle = '-', label ='SVM (auc = %0.3f)' % auc_svm)
plt.plot(logistic_fpr, logistic_tpr, marker = '-', label ='Logisctic (auc = %0.3f)' % auc_logistic)

plt.xlabel('False Positive Rate --->')
plt.ylabel('False Negative Rate --->')

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-cd8d9b6d60c6> in <cell line: 3>()
#       1 from sklearn.metrics import roc_curve, auc
#       2
# ----> 3 logistic_fpr, logistic_tpr, threshhold = roc_curve(y_test, y_pred_logistic)
#       4 auc_logistic = auc(logistic_fpr, logistic_tpr)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
#     993         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     994     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=4)
clf = clf.fit(X_train, y_train)

# %%
feature_names = X.columns
feature_names
# Out:
# Index(['Alcohol', 'Malicacid', 'Ash', 'Alcalinity_of_ash', 'Magnesium',
#        'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols',
#        'Proanthocyanins', 'Color_intensity', 'Hue', 'diluted_wines',
#        'Proline'],
#       dtype='object')

# %%
clf.feature_importances_
# Out:
# array([0.02367948, 0.        , 0.        , 0.02089322, 0.        ,
#        0.        , 0.42636236, 0.        , 0.        , 0.39598257,
#        0.        , 0.        , 0.13308236])

# %%
clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
predictions = clf.predict(X_test)
predictions
# Out:
# array([2, 3, 1, 2, 2, 1, 1, 2, 1, 1, 2, 2, 1, 3, 2, 3, 1, 3, 1, 1, 3, 2,
#        1, 1, 3, 2, 3, 3, 2, 2, 2, 2, 3, 2, 2, 2])

# %%
clf.predict_proba(X_test)
# Out:
# array([[0.02, 0.98, 0.  ],
#        [1.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.  , 0.  , 1.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [1.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [0.  , 0.  , 1.  ],
#        [0.02, 0.98, 0.  ],
#        [0.  , 0.  , 1.  ],
#        [0.02, 0.98, 0.  ],
#        [0.02, 0.98, 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.  , 0.  , 1.  ],
#        [0.  , 0.  , 1.  ],
#        [0.02, 0.98, 0.  ],
#        [0.  , 0.  , 1.  ],
#        [1.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.02, 0.98, 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.02, 0.98, 0.  ],
#        [1.  , 0.  , 0.  ],
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 0.9444444444444444

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions, labels = [0,1])
# Out:
# array([[ 0,  0],
#        [ 0, 12]])

# %%
from sklearn.linear_model import LogisticRegression

# liblinear solver works well with unscaled data
model = LogisticRegression(solver='liblinear')
# fit the model on the training data
model.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

y_test_predictions = model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_test_predictions)
conf_matrix
# Out:
# array([[12,  1,  0],
#        [ 0, 15,  0],
#        [ 0,  0,  8]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,8))
sns.set(font_scale = 1.5)

ax = sns.heatmap(
    conf_matrix, # confusion matrix 2D array
    annot=True, # show numbers in the cells
    fmt='d', # show numbers as integers
    cbar=False, # don't show the color bar
    cmap='flag', # customize color map
    vmax=175 # to get better color contrast
)

ax.set_xlabel("Predicted", labelpad=20)
ax.set_ylabel("Actual", labelpad=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ebaef5eb6511> in <cell line: 7>()
#       6
#       7 ax = sns.heatmap(
# ----> 8     conf_matrix, # confusion matrix 2D array
#       9     annot=True, # show numbers in the cells
#      10     fmt='d', # show numbers as integers
#
# NameError: name 'conf_matrix' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor


forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.9537706666666667

# %%
#precision = precision_score(y_test, y_test_predictions)
#recall = recall_score(y_test, y_test_predictions)
#f1score = f1_score(y_test, y_test_predictions)

#print(f"Precision = {precision}")
#print(f"Recall = {recall}")
#print(f"F1 Score = {f1score}")

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid =  {
    "n_estimators":[100, 200, 300],
    "min_sample_split":[2,4],
    "max_depth":[None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error",
                           return_train_score=True)

# %%
#grid_search.best_estimator_

#best_forest.score(X_test, y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
data =  RandomForestRegressor(n_estimators=10,
                               oob_score=True,
                               random_state=1)
data.fit(X_train, y_train) # learning
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:583: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=1)
